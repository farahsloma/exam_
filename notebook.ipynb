# %%
# from prompts import REWRITTER_PROMPT
from workflow import Workflow
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # from prompts import REWRITTER_PROMPT
# ----> 2 from workflow import Workflow
#
# ImportError: cannot import name 'Workflow' from 'workflow' (c:\Users\Farah\Downloads\expr\workflow.py)

# %%
REWRITTER_PROMPT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 REWRITTER_PROMPT
#
# NameError: name 'REWRITTER_PROMPT' is not defined
